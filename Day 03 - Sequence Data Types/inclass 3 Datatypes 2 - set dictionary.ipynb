# %% [markdown]
# ## 3. Set

# %% [markdown]
# A set is simply a collection of distinct objects.
# - un ordered - no first or last
# - { } - in maths, we use the same notation for sets
# - sets do not allow duplicates - auto removes duplicates
# - unindexed - no indexes and cannot use [0] or [1] etc

# %% [markdown]
# - https://www.geeksforgeeks.org/maths/sets/
# - [SET OPERATIONS](https://www.geeksforgeeks.org/maths/set-operations/)

# %%
items = { 1,2,3,4,5}

# %% [markdown]
# - can bag multiple types in SETs

# %%
itemsx = { 1,'2',3,'4'}
itemsx = { 1,'2',3,'4', (5,2) } # tuples

# %%
itemsx = { 1,'2',3,'4', [5,2] } # list will need indexes
itemsx = { 1,'2',3,'4', (5,2), {'a':1,'b':3} } # dictionaries
itemsx = { 1,'2',3,'4', (5,2), {'a','b',3} } # sets
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 itemsx = { 1,'2',3,'4', [5,2] } # list will need indexes
#       2 itemsx = { 1,'2',3,'4', (5,2), {'a':1,'b':3} } # dictionaries
#       3 itemsx = { 1,'2',3,'4', (5,2), {'a','b',3} } # sets
#
# TypeError: unhashable type: 'list'

# %%
items = {}
items
# Out:
# {}

# %%
# add more elements
items.add(8)

# discard an element
items.discard(8)

#clear - remove everything
items.clear()

# %%
item_list = list(items)
item_list

int(3.5)
int('3')
# Out:
# 3

# %%
list1 = [1,2,3,4,4,4,4,4,4,4,4,4,4]

# remove duplicates
set1 = set(list1)
list1 = list(set1)

# remove duplicates
list1 = list(set(list1))

list1
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# #### SET OPERATIONS

# %%
a = {1,2,3,4}
b = {3,4,5,6}

# %%
c = list(b)
c.reverse()
c.sort()

c
# Out:
# [3, 4, 5, 6]

# %%
# UNION
union_op = a | b
union_op = a.union(b)
union_op

# INTERSECTION
intersection_op = a & b
intersection_op = a.intersection(b)
intersection_op

# Difference
difference_op = a - b
difference_op = a.difference(b)
difference_op
# Out:
# {1, 2}

# %% [markdown]
# ### Examples:
# - where we can use sets?

# %%
# filters

# merging files

# remvoing duplicates
emails = ['eren@work.com','mikasa@work.com','eren@work.com','levi@work.com']

emails = list(set(emails))
emails

#
# Out:
# ['mikasa@work.com', 'levi@work.com', 'eren@work.com']

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Dictionary

# %% [markdown]
# - a set(or collection) of key - value pairs
# - used with these - `{ }` -
# - can store multiple types of data elements
# - can access elements by targets thier keys like ['key']
# -

# %%
student1 = {
    'name': 'idrees'
}

# %%
# saving different types of data in a single dictionary
# values can be anything - int float str bool list tuple dictionary
student1 = {
    'name': 'idrees',
    'regID': 2345,
    'subjects': ['poetry', 'maths', 'computer', 'physics'],
    'subjects_tuple': ('poetry', 'maths', 'computer', 'physics'),
    'subjects_set': {'poetry', 'maths', 'computer', 'physics'},
    'subjects_dict': {'sub1': 'poetry','sub2':  'maths','sub3':  'computer','sub4':  'physics'}
}

student1
# Out:
# {'name': 'idrees',
#  'regID': 2345,
#  'subjects': ['poetry', 'maths', 'computer', 'physics'],
#  'subjects_tuple': ('poetry', 'maths', 'computer', 'physics'),
#  'subjects_set': {'computer', 'maths', 'physics', 'poetry'},
#  'subjects_dict': {'sub1': 'poetry',
#   'sub2': 'maths',
#   'sub3': 'computer',
#   'sub4': 'physics'}}

# %%
# if keys are same!! 
# works just like a set
{
 'sub1': 'poetry',
 'sub1':  'maths',
 'sub1':  'computer',
 'sub1':  'physics' # last value is taken
}
# Out:
# {'sub1': 'physics'}

# %%
# what keys are accepted
# keys - Strings Integer Float Bool Tuple
# keys - can't be - list or dictionary - UNHASHABLE
# strings are mostly used
dict_a = { 'a' : 10}
dict_a
# Out:
# {'a': 10}

# %%
dict_a = { True : 10, False: 44, (): 33}
dict_a
# Out:
# {True: 10, False: 44, (): 33}

# %%
student1 = {
    'name': 'idrees',
    'regID': 2345,
    'subjects': ['poetry', 'maths', 'computer', 'physics']
}

# %% [markdown]
# ### Dictionary Operations

# %% [markdown]
# #### add - add a key value pair

# %%
student1['age'] = 89
# just access the dictionary, access a new key, that does not exist, and assign value
# it will be added to the dictionary

# %% [markdown]
# #### update - existing values

# %%
student1['name'] = 'Lina'

# %%
# we are accessing a list
student1['subjects'].append('philosophy')

# %%
student1['subjects'].remove('maths')

# %%
student1['subjects'].pop(3)
# Out:
# 'philosophy'

# %% [markdown]
# #### delete - a key value pair

# %%
del student1['age']

# %%
student1
# Out:
# {}

# %%
# student1['new_key] = new_value                # new key value pair
# student1['existing_key] = new_value           # modify/update existing key value pair
# del student1['existing_key]                   # delete an existing key value pair
# student1.clear() # will remove everything     # remove everything from dictionary
# new_copy_name = student1.copy()               # creates a new copy of the dictionary

# student1.items()                              # dict_items object to see everything inside
# student1.keys()                               # dict_keys object to get the keys only
# student1.values()                             # dict_values object to get the values only
# value_variable_name = student1.get('key')                           # save a value for a key

# %% [markdown]
# ### Loop over the dictionary

# %%
student1.items()
# Out:
# dict_items([('name', 'idrees'), ('regID', 2345), ('subjects', ['poetry', 'maths', 'computer', 'physics'])])

# %%
# carries 3 tuples
for i in student1.items():
    print(i)
# Out:
# ('name', 'idrees')
# ('regID', 2345)
# ('subjects', ['poetry', 'maths', 'computer', 'physics'])

# %%
for key, value in student1.items():
    print(key)
# Out:
# name
# regID
# subjects
# name
# regID
# subjects

# %%
# range
# list
# tuple

# dictionaries can't be iterated over
# Out:
# 0

# %%
for key in student1.keys():
    print(key)
# Out:
# name
# regID
# subjects

# %%
for value in student1.values():
    print(value)
# Out:
# idrees
# 2345
# ['poetry', 'maths', 'computer', 'physics']

# %%
student_name = student1.get('name')
student_name
# Out:
# 'idrees'

# %% [markdown]
# ### Excercise:
# - create a small dictionary:
# ```
# Name: Idrees
# Age: 24
# Course: AI/ML
# Attendance: 92
# Passed: True
# ```
#
# - change `age` to 38
# - change `Course` to `Subjects` save computer science, design, literature, poetry
# - get all the `items`, and print `keys` and `values`
