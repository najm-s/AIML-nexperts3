# %%
import idreeslibrary as IL

import numpy as np

# %%
IL.possesion_module.idrees
# Out:
# 121451

# %%
# importing FROM the module  some functions methods etc 
from idreeslibrary.possesion_module import Vehicles, Electronics, sum, new_function, multiply

# %%
idrees_mobile = Electronics()

# %%
IL.possesion_module.sum([1,2],[2,3])

# import matplotlib.pyplot as plt
# plt.show()



import idreeslibrary.possesion_module as pm
pm.idrees
# Out:
# 121451

# %%
new_function(2,3)

sum(3,4)

multiply(4,5)

# %%
IL.possesion_module.pi
